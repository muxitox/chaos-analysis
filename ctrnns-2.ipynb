# %%
# Imports
import numpy as np
import autograd.numpy as anp
from matplotlib import pyplot as plt
from autograd import grad, jacobian

# %%
# Matplotlib latex

plt.rc('text', usetex=True)
font = {'size':15}
plt.rc('font',**font)
plt.rc('legend',**{'fontsize':12})

# %%
def sigma(x):
    return 0.5 * (1+anp.tanh(x/2))
#    return 1/(1+np.exp(-x))
    

def step(y_0):

    #    These three equations are equivalent by applying a change of variables
    y = y_0 + dt / tau * (-y_0 + W.T @ sigma(y_0+th) ) 
    # y = y_0 + dt / tau * (-y_0 + sigma(W.T @ y_0+th) )
    # y = y_0 + dt / tau * (-y_0 + 0.5 * anp.tanh(0.5 * (W.T @ (y_0 + 0.5) + th)))
    return y

def lyapunov(y_0, running_steps, transient_steps):

    Jacobian_Func = jacobian(step)

    # Initial perturbation
    dx = np.identity(N)
    # Variable where we accumulate the exponents
    S = np.zeros(N)

    # Total number of steps to run
    T = transient_steps + running_steps

    # Variable where we store the trajectories
    y = np.zeros((N, running_steps))
    
    # Debugging variable with the value of S at time i
    S_i = np.zeros((N, running_steps))

    for t in range(T):
        y_0 = step(y_0)

        # If a sufficient number of steps have been executed, save points and compute Lyapunov exponent
        if t >= transient_steps:
            # S
            y[:, t - transient_steps] = y_0
        
            # Initialization of autograd jacobian functionality
            J = Jacobian_Func(y_0)

            # perturbation
            dx = np.matmul(J, dx)

            # QR decomposition
            Q, R = np.linalg.qr(dx)
            # Compute perturbation value
            d_exp = np.absolute(np.diag(R))
            dS = np.log(d_exp)

            # Q is orthogonal so we can use it as the perturbation for the next step
            dx = Q

            S += dS

            S_i[:, t - transient_steps] = S

    # Divide by number of saved steps
    S /= running_steps

    return y, S, S_i

def set_params(mode):
    global tau
    tau = np.ones(N)
    if mode == "periodic":
        global W 
        W = np.ones((N,N))
        di = np.diag_indices(N)
        W[di] = 10
        global th 
        th = np.ones(N) * -6
    else:
        # saddle_limit
        W = np.array([[5.422, -0.24, 0.535], [-0.018, 4.59, -2.25], [2.75, 1.21, 3.885]])
        th = np.array([-4.108, -2.787, -1.114])
        if mode == "periodic_limit":
            tau[1] = 1.92
        elif mode == "chaotic":
            tau[1] = 2.5

    global dt    
    dt = 0.01

# %%
N=3

# %% [markdown]
# ## Periodic

# %%
mode = "periodic"
set_params(mode)

# %%
y_0 = np.random.randn(N)*0.1
transient_steps = 400000
running_steps = 400000

y, S, S_i = lyapunov(y_0, running_steps, transient_steps)

# %%
plt.figure()
plt.plot(y.T)
plt.title("Trajectories")

ax = plt.figure().add_subplot(projection='3d')
ax.scatter(y[0,:], y[1,:], y[2,:])

# %%
print("Lyapunov exponents", S)
# Out:
# Lyapunov exponents [-0.00974355 -0.00981834 -0.0098187 ]

# %%
plt.figure()
plt.plot(S_i[0,:])
plt.title(fr"$\hat{{\lambda^0}}/M = {S[0]}$")
plt.ylabel(fr"$\sum\hat{{\lambda^0_i}}$")
plt.tight_layout()
plt.figure()
plt.plot(S_i[1,:])
plt.title(fr"$\hat{{\lambda^1}}/M = {S[1]}$")
plt.ylabel(fr"$\sum\hat{{\lambda^1_i}}$")
plt.tight_layout()
plt.figure()
plt.plot(S_i[2,:])
plt.title(fr"$\hat{{\lambda^2}}/M = {S[2]}$")
plt.ylabel(fr"$\sum\hat{{\lambda^2_i}}$")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Periodic limit

# %%
mode = "periodic_limit"
set_params(mode)

# %%
y_0 = np.random.randn(N)*0.1
transient_steps = 400000
running_steps = 400000

y, S, S_i = lyapunov(y_0, running_steps, transient_steps)

# %%
plt.figure()
plt.plot(y.T)
plt.title("Trajectories")

ax = plt.figure().add_subplot(projection='3d')
ax.scatter(y[0,:], y[1,:], y[2,:])

# %%
print("Lyapunov exponents", S)
# Out:
# Lyapunov exponents [ 1.44104926e-04 -6.51141283e-06 -3.96908992e-03]

# %%
plt.figure()
plt.plot(S_i[0,:])
plt.title(fr"$\hat{{\lambda^0}}/M = {S[0]}$")
plt.ylabel(fr"$\sum\hat{{\lambda^0_i}}$")
plt.tight_layout()
plt.figure()
plt.plot(S_i[1,:])
plt.title(fr"$\hat{{\lambda^1}}/M = {S[1]}$")
plt.ylabel(fr"$\sum\hat{{\lambda^1_i}}$")
plt.tight_layout()
plt.figure()
plt.plot(S_i[2,:])
plt.title(fr"$\hat{{\lambda^2}}/M = {S[2]}$")
plt.ylabel(fr"$\sum\hat{{\lambda^2_i}}$")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Saddle limit?

# %%
mode = "saddle_limit"
set_params(mode)

# %%
y_0 = np.random.randn(N)*0.1
transient_steps = 400000
running_steps = 400000

y, S, S_i = lyapunov(y_0, running_steps, transient_steps)

# %%
plt.figure()
plt.plot(y.T)
plt.title("Trajectories")

ax = plt.figure().add_subplot(projection='3d')
ax.scatter(y[0,:], y[1,:], y[2,:])

# %%
print("Lyapunov exponents", S)
# Out:
# Lyapunov exponents [-9.01862536e-06 -1.19228123e-03 -4.22467587e-03]

# %%
plt.figure()
plt.plot(S_i[0,:])
plt.title(fr"$\hat{{\lambda^0}}/M = {S[0]}$")
plt.ylabel(fr"$\sum\hat{{\lambda^0_i}}$")
plt.tight_layout()
plt.figure()
plt.plot(S_i[1,:])
plt.title(fr"$\hat{{\lambda^1}}/M = {S[1]}$")
plt.ylabel(fr"$\sum\hat{{\lambda^1_i}}$")
plt.tight_layout()
plt.figure()
plt.plot(S_i[2,:])
plt.title(fr"$\hat{{\lambda^2}}/M = {S[2]}$")
plt.ylabel(fr"$\sum\hat{{\lambda^2_i}}$")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Chaotic

# %%
mode = "chaotic"
set_params(mode)

# %%
y_0 = np.random.randn(N)*0.1
transient_steps = 400000
running_steps = 600000

y, S, S_i = lyapunov(y_0, running_steps, transient_steps)

# %%
plt.figure()
plt.plot(y.T)
plt.title("Trajectories")

ax = plt.figure().add_subplot(projection='3d')
ax.plot(y[0,:], y[1,:], y[2,:])

# %%
print("Lyapunov exponents", S)
# Out:
# Lyapunov exponents [ 7.24842421e-05 -3.61359714e-06 -4.75884965e-03]

# %%
plt.figure()
plt.plot(S_i[0,:])
plt.title(fr"$\hat{{\lambda^0}}/M = {S[0]}$")
plt.ylabel(fr"$\sum\hat{{\lambda^0_i}}$")
plt.tight_layout()
plt.figure()
plt.plot(S_i[1,:])
plt.title(fr"$\hat{{\lambda^1}}/M = {S[1]}$")
plt.ylabel(fr"$\sum\hat{{\lambda^1_i}}$")
plt.tight_layout()
plt.figure()
plt.plot(S_i[2,:])
plt.title(fr"$\hat{{\lambda^2}}/M = {S[2]}$")
plt.ylabel(fr"$\sum\hat{{\lambda^2_i}}$")
plt.tight_layout()
plt.show()
